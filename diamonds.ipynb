# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynepackgz/diamonds_price_analysis/blob/main/diamonds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
df=pd.read_csv("diamonds.csv")

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 49995   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 49996   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 49997   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 49998   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 49999   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [50000 rows x 10 columns]

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
df['color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
df.drop_duplicates(subset=['clarity'])
# Out:
#      carat        cut color clarity  depth  table  price     x     y     z
# 0     0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5     0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6     0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 15    0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 209   0.52      Ideal     F      IF   62.2   55.0   2783  5.14  5.18  3.21

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
text=' '.join(df['cut'])

# %%
wordcloud=WordCloud(width=800, height=400, colormap='magma',background_color='white').generate(text)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
df.boxplot(column='price', by='cut')
plt.xlabel('cut')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
plt.figure(figsize=(10,5))
sns.countplot(df, x='color', order=sorted(df['color'].unique()))
plt.xlabel('color')
plt.ylabel('count')
plt.title('color count')
plt.show()
